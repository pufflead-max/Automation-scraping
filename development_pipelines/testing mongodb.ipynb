# %%
from pymongo import MongoClient
import os

# %%
mongo_uri =  "mongodb://scraper_admin:Mongodb_password12345@72.60.113.252:47018/PUFF?authSource=PUFF"
# "mongodb://scraper_admin:Mongodb_password12345@mongo:47018/PUFF?authSource=PUFF"
client = MongoClient(mongo_uri)

# List databases
print(client.list_database_names())

# Insert test document
db = client["PUFF"]
db.test_collection.insert_one({"test": "local connection works"})
print(db.test_collection.find_one())
# Out:
# ['PUFF']
# {'_id': ObjectId('6955c89f1e139b37a888a586'), 'test': 'local connection works'}
