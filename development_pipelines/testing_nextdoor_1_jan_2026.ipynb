# %%
import requests

cookies = {
    'WE': '3ffe9d35-7f85-46ad-9ac6-485d42b5d8c2251209',
    'DAID': '74078636-0bc3-4ef3-aad2-ab5ed901f745251209',
    'ndp_session_id': '0ed283e9-cb45-497e-8f2d-2e2770bc8735',
    '_ga': 'GA1.1.84035976.1765315043',
    '_fbp': 'fb.1.1765315043297.453071599930428146',
    'WE3P': '3ffe9d35-7f85-46ad-9ac6-485d42b5d8c2251209',
    'g_state': '{"i_l":0,"i_ll":1765671916755,"i_b":"FjxvlVM5mQGl2f/PsPsWljmSdlVSXYMXIMNXsYb3DaQ","i_e":{"enable_itp_optimization":0}}',
    'csrftoken': 'lU5X61qi3LiQKxPhAHCNXhs1oKsbxpI93h6E4zxo682xhgEI4ZdS3XAkD4R6H0Vf',
    'role-invitation-decline-notification': 'false',
    'role-resignation-notification': 'false',
    '_gcl_au': '1.1.495346394.1765315036.522797601.1767024453.1767024452',
    'ndbr_at': 'UOEt0NWNjRE8PxStxb3mQ9UxMsFGC-MqNxMyLhKiU_Q',
    'ndbr_idt': 'eyJhbGciOiJSUzI1NiIsImtpZCI6IjU5YWU3NDRmLTRlOWQtNDBiNS1iZmFkLWQxMDYyZTBlOGIwMCIsInR5cCI6IkpXVCJ9..ieoSmcPHmiEzLHQLmfGVJBAg-ui6a96uHMHU0q96oNoP55osb2zVI5tbOzL5T9KoMgamurLxALx-JZpQXbybXwmcCrD2og_c9o6566X-73fW5Twlcb4RKfdT3_XvlBnlg137Gt7zECN56lyXlYuOV4pUFW7-4ifcGxThGAOT10Y2IJ5_8tm_ckehu9V4XGmB1lFHJJyWOJ3cgPZrFO1lY4_i7lY78KxzINIUS1tlPwM6zSgeq7PVKARMLoaErmPl9LYe9PTH7WJUFGJvUG1-t5RSGrLLATL_A0edc9fCctpOnDbOqBE9pS-s3F8Jl-aC-9uBr5O4cXWXk_ALOOA62A',
    'ndbr_adt': '"{\'ac3965de-ad99-4377-a200-5e333f907ba4\': \'UOEt0NWNjRE8PxStxb3mQ9UxMsFGC-MqNxMyLhKiU_Q\'}"',
    'ndp_last_fired_date': '2026-01-01',
    '_uetsid': '831638c0e74911f0b981855f94a17ffe',
    '_uetvid': '408e1ce0c81911f0b75571c22354cc3b',
    '_ga_HND6C6XLY7': 'GS2.1.s1767296343$o10$g0$t1767296343$j60$l0$h1221711189',
    '_ga_L2ES4MTTT0': 'GS2.1.s1767296345$o8$g0$t1767296345$j60$l0$h0',
    'flaskTrackReferrer': 'b7acba14-eb0a-4702-ad42-46dfdb2d2785',
    '_dd_s': 'logs=1&id=59217184-615d-4ab1-aadd-37f9e1ba47ae&created=1767296324402&expire=1767297422526',
}

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'no-cache',
    'content-type': 'application/json',
    'enable-alphafeed': 'false',
    'origin': 'https://nextdoor.com',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://nextdoor.com/news_feed/',
    'sec-ch-ua': '"Google Chrome";v="143", "Chromium";v="143", "Not A(Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36',
    'x-csrftoken': 'lU5X61qi3LiQKxPhAHCNXhs1oKsbxpI93h6E4zxo682xhgEI4ZdS3XAkD4R6H0Vf',
    'x-nd-activity-id': '31e54aab-c116-4081-8a9c-974275653834',
    'x-nd-activity-source': 'resumed',
    'x-nd-activity-ts': '1767296400071',
    'x-nd-cts': '1767296523413',
    'x-nd-ecp': '',
    'x-nd-eid': '',
    'x-nd-lop': '',
    'x-nd-lox': 'false',
    'x-nd-lsuid': '',
    'x-nd-ndas-trigger': 'tab_change',
    'x-nd-pre-max-act': 'null',
    'x-nd-pre-max-nav': 'null',
    'x-nd-pre-max-view': 'null',
    'x-nd-pre-ndai': 'aafbf1b1-f224-457b-8612-7dbc767461a6',
    'x-nd-pre-ndai-src': 'user_backgrounded',
    'x-nd-pre-ndai-ts': '1767296340948',
    'x-nd-request-locale': 'US',
    'x-nd-train': 'train-26876-2c563eda8648c49f',
    'x-nd-uti': '96a68991-f477-4d37-825f-ce14a08827e9',
    'x-nd-wv': 'false',
    # 'cookie': 'WE=3ffe9d35-7f85-46ad-9ac6-485d42b5d8c2251209; DAID=74078636-0bc3-4ef3-aad2-ab5ed901f745251209; ndp_session_id=0ed283e9-cb45-497e-8f2d-2e2770bc8735; _ga=GA1.1.84035976.1765315043; _fbp=fb.1.1765315043297.453071599930428146; WE3P=3ffe9d35-7f85-46ad-9ac6-485d42b5d8c2251209; g_state={"i_l":0,"i_ll":1765671916755,"i_b":"FjxvlVM5mQGl2f/PsPsWljmSdlVSXYMXIMNXsYb3DaQ","i_e":{"enable_itp_optimization":0}}; csrftoken=lU5X61qi3LiQKxPhAHCNXhs1oKsbxpI93h6E4zxo682xhgEI4ZdS3XAkD4R6H0Vf; role-invitation-decline-notification=false; role-resignation-notification=false; _gcl_au=1.1.495346394.1765315036.522797601.1767024453.1767024452; ndbr_at=UOEt0NWNjRE8PxStxb3mQ9UxMsFGC-MqNxMyLhKiU_Q; ndbr_idt=eyJhbGciOiJSUzI1NiIsImtpZCI6IjU5YWU3NDRmLTRlOWQtNDBiNS1iZmFkLWQxMDYyZTBlOGIwMCIsInR5cCI6IkpXVCJ9..ieoSmcPHmiEzLHQLmfGVJBAg-ui6a96uHMHU0q96oNoP55osb2zVI5tbOzL5T9KoMgamurLxALx-JZpQXbybXwmcCrD2og_c9o6566X-73fW5Twlcb4RKfdT3_XvlBnlg137Gt7zECN56lyXlYuOV4pUFW7-4ifcGxThGAOT10Y2IJ5_8tm_ckehu9V4XGmB1lFHJJyWOJ3cgPZrFO1lY4_i7lY78KxzINIUS1tlPwM6zSgeq7PVKARMLoaErmPl9LYe9PTH7WJUFGJvUG1-t5RSGrLLATL_A0edc9fCctpOnDbOqBE9pS-s3F8Jl-aC-9uBr5O4cXWXk_ALOOA62A; ndbr_adt="{\'ac3965de-ad99-4377-a200-5e333f907ba4\': \'UOEt0NWNjRE8PxStxb3mQ9UxMsFGC-MqNxMyLhKiU_Q\'}"; ndp_last_fired_date=2026-01-01; _uetsid=831638c0e74911f0b981855f94a17ffe; _uetvid=408e1ce0c81911f0b75571c22354cc3b; _ga_HND6C6XLY7=GS2.1.s1767296343$o10$g0$t1767296343$j60$l0$h1221711189; _ga_L2ES4MTTT0=GS2.1.s1767296345$o8$g0$t1767296345$j60$l0$h0; flaskTrackReferrer=b7acba14-eb0a-4702-ad42-46dfdb2d2785; _dd_s=logs=1&id=59217184-615d-4ab1-aadd-37f9e1ba47ae&created=1767296324402&expire=1767297422526',
}

params = ''

json_data = {
    'operationName': 'PersonalizedFeed',
    'variables': {
        'pagedCommentsMode': 'FEED',
        'includeModerationInfo': False,
        'mainFeedArgs': {
            'pageSize': 1000,
            'nextPage': None, #'...',
            'supportedFeatures': {
                'rollupTypes': [
                    'CAROUSEL',
                    'LIST',
                    'GRID',
                ],
                'rollupItemTypes': [
                    'IMAGE_CARD',
                    'LIST_CARD',
                    'POST',
                    'PUBLISHER_DISCOVERY',
                    'ONBOARDING_CAROUSEL_CARD',
                ],
                'numCommentsForNewsPosts': 2,
                'isCommentRankedByRelevance': False,
            },
            'sortOrder': 'RECENT_POSTS',
            'feedRequestId': '8c29bc27-aa3c-40f2-813b-4d34ed1499a5',
        },
        'timeZone': 'Africa/Cairo',
    },
    'extensions': {
        'persistedQuery': {
            'version': 1,
            'sha256Hash': 'b416264b6fcbca3bec23ac002bba373679f002c09e28ba0f4884c7edc0838718',
        },
    },
}



params = ''

json_data = {
    'operationName': 'PersonalizedFeed',
    'variables': {
        'pagedCommentsMode': 'FEED',
        'includeModerationInfo': False,
        'mainFeedArgs': {
            'pageSize': 1000,
            'nextPage': None,
            'supportedFeatures': {
                'rollupTypes': [
                    'CAROUSEL',
                    'LIST',
                    'GRID',
                ],
                'rollupItemTypes': [
                    'IMAGE_CARD',
                    'LIST_CARD',
                    'POST',
                    'PUBLISHER_DISCOVERY',
                    'ONBOARDING_CAROUSEL_CARD',
                ],
                'numCommentsForNewsPosts': 2,
                'isCommentRankedByRelevance': False,
            },
            'sortOrder': 'RECENT_POSTS',
            'feedRequestId': '716e2762-0ea0-4118-83bf-47b1168081e6',
        },
        'timeZone': 'Africa/Cairo',
    },
    'extensions': {
        'persistedQuery': {
            'version': 1,
            'sha256Hash': 'b416264b6fcbca3bec23ac002bba373679f002c09e28ba0f4884c7edc0838718',
        },
    },
}



res = requests.post(
    'https://nextdoor.com/api/gql/PersonalizedFeed',
    params=params,
    cookies=cookies,
    headers=headers,
    json=json_data,
)

# Note: json_data will not be serialized by requests
# exactly as it was in the original request.
#data = '{"operationName":"PersonalizedFeed","variables":{"pagedCommentsMode":"FEED","includeModerationInfo":false,"mainFeedArgs":{"pageSize":10,"nextPage":"...","supportedFeatures":{"rollupTypes":["CAROUSEL","LIST","GRID"],"rollupItemTypes":["IMAGE_CARD","LIST_CARD","POST","PUBLISHER_DISCOVERY","ONBOARDING_CAROUSEL_CARD"],"numCommentsForNewsPosts":2,"isCommentRankedByRelevance":false},"sortOrder":"RECENT_POSTS","feedRequestId":"8c29bc27-aa3c-40f2-813b-4d34ed1499a5"},"timeZone":"Africa/Cairo"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"b416264b6fcbca3bec23ac002bba373679f002c09e28ba0f4884c7edc0838718"}}}'
#response = requests.post('https://nextdoor.com/api/gql/PersonalizedFeed', params=params, cookies=cookies, headers=headers, data=data)


print(res)
len(res.text)
# Out:
# <Response [200]>
# 4167913

# %%
j_data = res.json()

# %%
j_data.keys()
# Out:
# dict_keys(['data'])

# %%
j_data["data"].keys()
# Out:
# dict_keys(['me', 'requestId'])

# %%
j_data["data"]["me"].keys()
# Out:
# dict_keys(['personalizedFeed', 'user', '__typename'])

# %%
j_data["data"]["me"]["personalizedFeed"].keys()
# Out:
# dict_keys(['adArgsError', 'pinnedPostError', 'feedItems', 'nextPage', 'firstPage', 'promos', 'materializedViewId', 'audienceTargetingKvs', 'liveLocalUpdatesSpotlight', 'sortOrderOptions', 'sortOrder', '__typename'])

# %%
items = j_data["data"]["me"]["personalizedFeed"]["feedItems"]

# %%
len(items)
# Out:
# 264

# %%
items[:5]
# Out:
# [{'feedItemType': 'POST',
#   'legacyAnalyticsId': '448766657',
#   'trackingId': '224878e1-6944-4567-9713-4d4342b475dc',
#   'contentId': '448766657',
#   'contentType': 'post',
#   'analyticsPayload': '{"is_agency_post": false, "post_type": "USER", "country": "US", "platform": "web", "web_type": "desktop", "neighborhood_id": 407950}',
#   'post': {'id': 'post_448766657',
#    'actions': {'bookmarking': {'isEnabled': True,
#      'isVisible': False,
#      'disabledReason': None,
#      'clickAction': None,
#      'bypassVerification': False,
#      '__typename': 'PostAction'},
#     'reacting': {'isEnabled': True,
#      'isVisible': True,
#      'disabledReason': None,
#      'clickAction': None,
#      'bypassVerification': False,
#      '__typename': 'PostAction'},
#     'commenting': {'isEnabled': True,
#      'isVisible': True,
#      'disabledReason': None,
#      'clickAction': None,
#      'bypassVerification': False,
#      '__typename': 'PostAction'},
# ...

# %%
item = items[0]

# %%
item.keys()
# Out:
# dict_keys(['feedItemType', 'legacyAnalyticsId', 'trackingId', 'contentId', 'contentType', 'analyticsPayload', 'post', 'topHats', 'displayOptionsMenu', 'hidden', 'ctaRow', 'virtualGiftView', 'userFeedback', '__typename'])

# %%
for k in item:
    print("======================================")
    print(k)
    print("------------------")
    print(item[k])
# Out:
# ...
# feedItemType
# ------------------
# POST
# ...
# legacyAnalyticsId
# ------------------
# 448765095
# ...
# trackingId
# ------------------
# 297aa8b3-bd1c-4b46-8a73-80c441ec462a
# ...
# contentId
# ------------------
# 448765095
# ...
# contentType
# ------------------
# post
# ...
# analyticsPayload
# ------------------
# {"is_agency_post": false, "post_type": "USER", "country": "US", "platform": "web", "web_type": "desktop", "neighborhood_id": 407950}
# ...
# post
# ------------------
# ...

# %%
j_data["data"]["me"]["personalizedFeed"]["nextPage"]

# %%
j_data["data"]["me"]["personalizedFeed"]["sortOrder"]
# Out:
# 'RECENT_POSTS'

# %%
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
items =

# %%
j_data = response.json()

# %%
len(response.text)
# Out:
# 215571

# %%
Perfect, thank you 👍  
This approach makes sense and I like the separation between login module and scraping module.

Just to be clear and aligned:
– No permanent password storage
– Session / token based login is fine
– Validation check before re-login
– Manual reset option if needed

About data storage, VPS database access is great 👍  
I just want to make sure PUFF data is always accessible and portable.

Next step from my side:
Landscape + Hardscape keywords are confirmed.
After this, I’d like:
– basic data structure (lead fields)
– simple flow diagram of the scraping → storage → output

This will help us lock the MVP and move fast.

# %%
Yes, using ChatGPT for classification makes sense 👍  

For MVP, I’d like to keep it as a validation layer, not the first filter.
Flow idea:
– First: keyword + rule-based filtering
– Then: ChatGPT only to confirm if it’s a real lead or normal discussion

ChatGPT output can be very simple for now:
– LEAD (high / medium intent)
– NOT A LEAD

This keeps cost low, logic clear, and results consistent.
We can make it more advanced later if needed.

# %%
Great. Here is the PUFF Lead Data Schema v1 (MVP) so we lock the database and outputs.

Required fields:
- lead_id (UUID)
- platform (nextdoor)
- service_category (landscape | hardscape)
- keyword_matched
- post_text
- post_url (if available)
- author_name (if available)
- author_profile_url (if available)
- location_text
- city_target
- post_created_at (if available)
- scraped_at
- is_lead (true/false)
- intent_level (high/medium/low)
- status (new/qualified/sent/ignored/duplicate)
- dedupe_hash (text+author+date)

Optional (nice to have):
- contact_hint (if any phone/email appears)
- job_type (maintenance/cleanup/install/repair/unknown)
- season_tag (fall_cleanup/snow/general/unknown)

If we use GPT for validation:
- classifier_source (rules / gpt / rules+gpt)
- classifier_version (v1)
- classifier_reason_short (short string)

Sending fields (for later integration):
- sent_at
- sent_channel (email/webhook/ghl/manual)
- sent_to
- send_result (success/fail)
- send_error

Rule: create lead only when keyword + original post + recent.
Duplicates handled by dedupe_hash.
